# %%
'''
The test code starts here
'''

import phase_correction as fun
#import fun2 as fun
#Loading image file (hologram) to process
user_input = '4cm_20x_bigcakes_square.tif'
filename = 'input/' + user_input
print ('Non-telecentric DHM hologram: ', filename)

Lambda = 532*10**(-9)
#Lambda = 633*10**(-9)
dx = 6.9*10**(-6)
dy = 6.9*10**(-6)

# Numerical compensation using an automatic method to determine the +1 ROI and center of the spherical phase factor
output = fun.phase_correction(filename, Lambda, dx, dy, 2, 50)
# Out:
# Non-telecentric DHM hologram:  input/4cm_20x_bigcakes_square.tif
# Optimized C:  1.425578813123155
